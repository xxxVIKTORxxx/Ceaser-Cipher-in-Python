# %%
def encrypt(text,s):
    result = ""
   # transverse the plain text
    for i in range(len(text)):
        char = text[i]
      # Encrypt uppercase characters in plain text
      
        if (char.isupper()):
            result += chr((ord(char) + s-65) % 26 + 65)
      # Encrypt lowercase characters in plain text
        else:
            result += chr((ord(char) + s - 97) % 26 + 97)
    return result
#check the above function
text = "CEASER CIPHER Demo"
s = 16

print("Plain Text : " + text)
print("Shift pattern : " + str(s))
print("Cipher: " + encrypt(text,s))
# Out:
# Plain Text : CEASER CIPHER Demo
# Shift pattern : 16
# Cipher: SUQIUHdSYFXUHdTuce

# %%
# Brute Force Technique

message = 'SUQIUHdSYFXUHdTuce' #encrypted message
LETTERS = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'
letters_low = LETTERS.lower()

for key in range(len(LETTERS)):
    translated = ''
    for symbol in message:
        if symbol in LETTERS:
            num = LETTERS.find(symbol)
            num = num - key
            if num < 0:
                num = num + len(LETTERS)
            translated = translated + LETTERS[num]
        elif symbol in letters_low: 
            num_l = letters_low.find(symbol)
            num_l = num_l - key
            if num_l <0:
                num_l = num_l + len(letters_low)
            translated = translated + letters_low[num_l]
        else:
            translated = translated + symbol
    print('Hacking key #%s: %s' % (key, translated))
# Out:
# Hacking key #0: SUQIUHdSYFXUHdTuce
# Hacking key #1: RTPHTGcRXEWTGcStbd
# Hacking key #2: QSOGSFbQWDVSFbRsac
# Hacking key #3: PRNFREaPVCUREaQrzb
# Hacking key #4: OQMEQDzOUBTQDzPqya
# Hacking key #5: NPLDPCyNTASPCyOpxz
# Hacking key #6: MOKCOBxMSZROBxNowy
# Hacking key #7: LNJBNAwLRYQNAwMnvx
# Hacking key #8: KMIAMZvKQXPMZvLmuw
# Hacking key #9: JLHZLYuJPWOLYuKltv
# Hacking key #10: IKGYKXtIOVNKXtJksu
# Hacking key #11: HJFXJWsHNUMJWsIjrt
# Hacking key #12: GIEWIVrGMTLIVrHiqs
# Hacking key #13: FHDVHUqFLSKHUqGhpr
# Hacking key #14: EGCUGTpEKRJGTpFgoq
# Hacking key #15: DFBTFSoDJQIFSoEfnp
# Hacking key #16: CEASERnCIPHERnDemo
# Hacking key #17: BDZRDQmBHOGDQmCdln
# Hacking key #18: ACYQCPlAGNFCPlBckm
# Hacking key #19: ZBXPBOkZFMEBOkAbjl
# Hacking key #20: YAWOANjYELDANjZaik
# Hacking key #21: XZVNZMiXDKCZMiYzhj
# Hacking key #22: WYUMYLhWCJBYLhXygi
# Hacking key #23: VXTLXKgVBIAXKgWxfh
# Hacking key #24: UWSKWJfUAHZWJfVweg
# Hacking key #25: TVRJVIeTZGYVIeUvdf
